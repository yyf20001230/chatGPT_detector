# %%
import openai

# %%
openai.api_key = "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"
response = openai.Completion.create(
  engine="davinci",
  prompt="What is AI? Present your response in waves of 100 tokens or less.",
  max_tokens=1900,
  temperature=0.9,
)
print(response.choices[0].text)
# Out:
# 1 wave = 100 tokens
#
# My response has 3 waves
#
# Wave 0: Definition
#
# Wave 1: Elegance
#
# Wave 2: Safety
#
# AI is a ________________________________________________________________________
#
# Think about the question,
#
# “More human like or more robotic?”
#
# Then choose one of the following:
#
# More like human – 100 tokens
#
# More robotic – 100 tokens
#
# Nobody cares – 100 tokens
#
# The 100 tokens can be distributed over the three waves.
#
# You have 2 minutes to submit to the wave you selected.
#
# Wave Response
#
# Wave 0: Definitions of AI
#
# Wave 1: Elegance
#
# Wave 2: Safety
#
# Wave 0: AI Definition
#
# Adam Shostack on Twitter:
#
# “AI is a system that exhibits intelligence, not a property of people or a quality of machines.”
#
# @shostack
#
# @akshostack
#
# “The capacity of a machine to perform functions that are normally associated with human beings.”
#
# “Intelligence is the ability to achieve complex goals.”
#
# ...

# %%
from revChatGPT.V1 import Chatbot

chatbot = Chatbot(config={
  "email": "frankyang2024@u.northwestern.edu",
  "password": "720809Zj.",
})

for data in chatbot.ask(
  "What is AI? Present your response in waves of 100 tokens or less.",
  conversation_id=chatbot.config.get("conversation"),
  parent_id=chatbot.config.get("parent_id"),
):
  print(data["message"], end="", flush = True)
print()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /Users/frank/Downloads/IEEE 23/chatGPT_detector/test.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/frank/Downloads/IEEE%2023/chatGPT_detector/test.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> from revChatGPT.V1 import Chatbot
# ----> <a href='vscode-notebook-cell:/Users/frank/Downloads/IEEE%2023/chatGPT_detector/test.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> chatbot = Chatbot(config={
#       <a href='vscode-notebook-cell:/Users/frank/Downloads/IEEE%2023/chatGPT_detector/test.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>   "email": "frankyang2024@u.northwestern.edu",
#       <a href='vscode-notebook-cell:/Users/frank/Downloads/IEEE%2023/chatGPT_detector/test.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>   "password": "720809Zj.",
# ...
